# %% [markdown]
# Name : Tanvi Gajanan Upganlawar
#
# PRN : 1252090012
#
# Roll no : 12
#
#
# ---

# %% [markdown]
# Assignment 1
#
# Perform the following operations using Python on suitable data sets:
#
# Read data from different formats (like csv, xls),
# Find Shape of Data,
# Find Missing Values,
# Find data type of each column,
# Finding out Zero's,
# Indexing and selecting data, sort data,
# Describe attributes of data, checking data types of each column,
# counting unique values of data, format of each column, converting variable data type (e.g. from long to short, vice versa)

# %% [markdown]
# Read data from different formats(like csv, xls)

# %%
import pandas as pd
df = pd.read_csv("house.csv")
print(df)
# Out:
#     Id    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0    1  1360.0         5        4.0       3     1970.0  Downtown  Excellent
# 1    2  4272.0         5        4.0       3     1958.0  Downtown  Excellent
# 2    3  3592.0         2        NaN       3     1938.0  Downtown       Good
# 3    4   966.0         4        2.0       2     1902.0  Suburban       Fair
# 4    5  4926.0         1        4.0       2     1975.0  Downtown       Fair
# 5    6  3944.0         1        2.0       1     1906.0     Urban       Poor
# 6    7  3671.0         1        1.0       2     1948.0     Rural       Poor
# 7    8     NaN         2        4.0       1     1925.0  Suburban       Good
# 8    9   630.0         2        2.0       1     1932.0     Rural       Poor
# 9   10  2185.0         3        3.0       1     2000.0  Downtown       Poor
# 10  11  1269.0         1        4.0       2     1947.0  Suburban       Poor
# ...

# %% [markdown]
# Find shape of data

# %%
print("Shape of data:", df.shape)
# Out:
# Shape of data: (30, 10)

# %% [markdown]
# Find missing values

# %%
print("Missing values :", df.isnull().sum())
# Out:
# Missing values : Id           0
# Area         1
# Bedrooms     0
# Bathrooms    1
# Floors       0
# YearBuilt    1
# Location     0
# Condition    0
# Garage       1
# Price        0
# dtype: int64

# %% [markdown]
# Find data type of each column

# %%
print("Data Types :", df.dtypes)
# Out:
# Data Types : Id             int64
# Area         float64
# Bedrooms       int64
# Bathrooms    float64
# Floors         int64
# YearBuilt    float64
# Location      object
# Condition     object
# Garage        object
# Price          int64
# dtype: object

# %% [markdown]
# Finding out Zero's

# %%
print("Zero values count : ", (df==0).sum())
# Out:
# Zero values count :  Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        1
# dtype: int64

# %%
Selecting data

# %%
print(df[['Id','Area']])
# Out:
#     Id    Area
# 0    1  1360.0
# 1    2  4272.0
# 2    3  3592.0
# 3    4   966.0
# 4    5  4926.0
# 5    6  3944.0
# 6    7  3671.0
# 7    8     NaN
# 8    9   630.0
# 9   10  2185.0
# 10  11  1269.0
# 11  12  2891.0
# 12  13  2933.0
# 13  14  1684.0
# 14  15  3885.0
# 15  16  4617.0
# 16  17  3404.0
# 17  18   974.0
# 18  19  1582.0
# 19  20  3058.0
# 20  21  2547.0
# 21  22  3247.0
# 22  23  1475.0
# 23  24  2306.0
# 24  25   689.0
# 25  26  3234.0
# 26  27  3505.0
# 27  28  2399.0
# 28  29  1767.0
# 29  30  2028.0

# %% [markdown]
# Indexing  data

# %%
print(df.loc[0:2])
# Out:
#    Id    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360.0         5        4.0       3     1970.0  Downtown  Excellent
# 1   2  4272.0         5        4.0       3     1958.0  Downtown  Excellent
# 2   3  3592.0         2        NaN       3     1938.0  Downtown       Good
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746

# %% [markdown]
# sorting data

# %%
print(df.sort_values(by='Area', ascending=False))
# Out:
#     Id    Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 4    5  4926.0         1        4.0       2     1975.0  Downtown       Fair
# 15  16  4617.0         1        4.0       2        NaN  Downtown       Poor
# 1    2  4272.0         5        4.0       3     1958.0  Downtown  Excellent
# 5    6  3944.0         1        2.0       1     1906.0     Urban       Poor
# 14  15  3885.0         1        3.0       1     1970.0     Urban       Fair
# 6    7  3671.0         1        1.0       2     1948.0     Rural       Poor
# 2    3  3592.0         2        NaN       3     1938.0  Downtown       Good
# 26  27  3505.0         4        2.0       3     1955.0     Urban       Good
# 16  17  3404.0         2        1.0       1     1903.0     Urban       Fair
# 21  22  3247.0         4        3.0       1     1931.0  Downtown  Excellent
# 25  26  3234.0         5        4.0       2     1959.0     Urban       Good
# ...

# %% [markdown]
# describe attributes of data

# %%
print(df.describe())
# Out:
#               Id         Area   Bedrooms  Bathrooms     Floors    YearBuilt  \
# count  30.000000    29.000000  30.000000  29.000000  30.000000    29.000000
# mean   15.500000  2587.586207   2.766667   2.758621   1.866667  1950.413793
# std     8.803408  1212.574726   1.454679   1.154345   0.819307    35.727658
# min     1.000000   630.000000   1.000000   1.000000   1.000000  1900.000000
# 25%     8.250000  1582.000000   2.000000   2.000000   1.000000  1927.000000
# 50%    15.500000  2547.000000   2.000000   3.000000   2.000000  1947.000000
# 75%    22.750000  3505.000000   4.000000   4.000000   2.750000  1975.000000
# max    30.000000  4926.000000   5.000000   4.000000   3.000000  2016.000000
#
#                Price
# count      30.000000
# mean   513216.966667
# std    289340.846015
# min         0.000000
# 25%    249701.500000
# 50%    497508.500000
# 75%    709921.750000
# max    996357.000000

# %% [markdown]
# counting unique values of data

# %%
print(df.nunique())
# Out:
# Id           30
# Area         29
# Bedrooms      5
# Bathrooms     4
# Floors        3
# YearBuilt    28
# Location      4
# Condition     4
# Garage        2
# Price        30
# dtype: int64

# %% [markdown]
# format of each column

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         30 non-null     int64
#  1   Area       29 non-null     float64
#  2   Bedrooms   30 non-null     int64
#  3   Bathrooms  29 non-null     float64
#  4   Floors     30 non-null     int64
#  5   YearBuilt  29 non-null     float64
#  6   Location   30 non-null     object
#  7   Condition  30 non-null     object
#  8   Garage     29 non-null     object
#  9   Price      30 non-null     int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 2.5+ KB
# None

# %% [markdown]
# converting variable data types

# %%
df['Id'] = df['Id'].astype('int32')
df['Bedrooms'] = df['Bedrooms'].astype('float')

# %% [markdown]
# Create your dataframe for given student attributes:
#
# Student_Id,Name,Age,Gender,Dept,Marks,Attendence,Internship

# %%
data = {'Student_Id':[1,2,3,4,5],
        'Name':['rose','john','jack','max','alen'],
        'Age':[18,19,19,20,18],
        'Gender':['female','male','male','male','male'],
        'Dept':['CS','CSAI','AIML','AIDS','CSAI'],
        'Marks':[90,95,92,89,85],
        'Attendance':[76,89,80,98,91],
        'Internship':['yes','no','yes','no','yes']
        }

df2 = pd.DataFrame(data)
print(df2)
# Out:
#    Student_Id  Name  Age  Gender  Dept  Marks  Attendance Internship
# 0           1  rose   18  female    CS     90          76        yes
# 1           2  john   19    male  CSAI     95          89         no
# 2           3  jack   19    male  AIML     92          80        yes
# 3           4   max   20    male  AIDS     89          98         no
# 4           5  alen   18    male  CSAI     85          91        yes

# %% [markdown]
# Find the shape of the data

# %%
print("Shape of data: ", df2.shape)
# Out:
# Shape of data:  (5, 8)

# %% [markdown]
# Find the missing values

# %%
print("Missing values:\n", df2.isnull().sum())
# Out:
# Missing values:
#  Student_Id    0
# Name          0
# Age           0
# Gender        0
# Dept          0
# Marks         0
# Attendance    0
# Internship    0
# dtype: int64

# %% [markdown]
# Find data type of each column

# %%
print("Data types:\n", df2.dtypes)
# Out:
# Data types:
#  Student_Id     int64
# Name          object
# Age            int64
# Gender        object
# Dept          object
# Marks          int64
# Attendance     int64
# Internship    object
# dtype: object

# %% [markdown]
# Finding out zero's

# %%
print("Zero values count:\n", (df2 == 0).sum())
# Out:
# Zero values count:
#  Student_Id    0
# Name          0
# Age           0
# Gender        0
# Dept          0
# Marks         0
# Attendance    0
# Internship    0
# dtype: int64
